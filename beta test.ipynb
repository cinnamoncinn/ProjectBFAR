# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = "D:/Downloads/ojt/dataset.csv"  # Ensure this is the correct path

df = pd.read_csv(file_path)

# %%
# Display basic info
display(df.info())
display(df.head())

def plot_categorical_columns(df):
    categorical_cols = df.select_dtypes(include=['object']).columns
    for col in categorical_cols:
        plt.figure(figsize=(10, 4))
        df[col].value_counts().plot(kind='bar', color='skyblue')
        plt.title(f"Distribution of {col}")
        plt.xticks(rotation=45)
        plt.xlabel(col)
        plt.ylabel("Count")
        plt.show()

# Plot numerical distributions
def plot_numerical_columns(df):
    numerical_cols = df.select_dtypes(include=['number']).columns
    for col in numerical_cols:
        plt.figure(figsize=(8, 4))
        sns.histplot(df[col].dropna(), kde=True, bins=30)
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.show()

# Correlation heatmap
def plot_correlation_matrix(df):
    plt.figure(figsize=(12, 8))
    numeric_df = df.select_dtypes(include=['number'])
    correlation_matrix = numeric_df.corr()
    sns.heatmap(correlation_matrix, annot=False, cmap="coolwarm", fmt=".2f")
    plt.title("Correlation Matrix")
    plt.show()

# Call functions to generate plots
plot_categorical_columns(df)
plot_numerical_columns(df)
plot_correlation_matrix(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Columns: 136 entries, A1:AREA to J7.5
# dtypes: float64(42), object(94)
# memory usage: 2.2+ MB
# None
#   A1:AREA     A2:GROUP  B3:AGE B5:SEX B6:M-STATUS B7:EDUCATION  \
# 0  ABULUG  BENEFICIARY    33.0   Male     Married  High School
# 1  ABULUG  BENEFICIARY    57.0   Male     Livedin  High School
# 2  ABULUG  BENEFICIARY    45.0   Male     Married  High School
# 3  ABULUG  BENEFICIARY    32.0   Male      Single  High School
# 4  ABULUG  BENEFICIARY    38.0   Male      Single  High School
#
#   B8:Household Size C1:TOT_INCOME/A C2:INCOME/B/FISH C4:INCOME/B/ALT  ...  \
# 0       4-6 members             10K              10K             10K  ...
# 1       4-6 members             10K              10K             10K  ...
# 2       4-6 members             10K              10K             10K  ...
# 3       7-9 members             10K              10K             10K  ...
# 4       1-3 members             10K              10K             10K  ...
#
#    J6.2 J6.3 J6.4 J6.5 J6.6 J7.1 J7.2 J7.3 J7.4 J7.5
# 0   4.0  5.0  5.0  5.0  5.0  3.0  3.0  5.0  5.0  5.0
# 1   5.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0
# 2   5.0  5.0  4.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0
# 3   1.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0  5.0
# 4   5.0  5.0  5.0  5.0  5.0  1.0  5.0  5.0  5.0  5.0
#
# [5 rows x 136 columns]
